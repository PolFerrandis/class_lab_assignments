# %%
# !ls
# Out:
# Lab | Customer Analysis Round 2.ipynb
# casestudyH4All.ipynb
# data for class.zip
# dataforclass
# date_time_class.ipynb
# file4.xlsx
# healthcare for all column definitions.docx

# %%
import pandas as pd
import numpy as np

# %%
cd ..
# Out:
# /

# %%
cd/Users/polferrandis/Documents/Github/class_lab_assignments/week1
# Out:
# /Users/polferrandis/Documents/Github/class_lab_assignments/Week1

# %%
# !ls
# Out:
# Carinsurance                     marketing_customer_analysis.xlsx
# Jupyterlab.ipynb

# %%
df=pd.read_excel('marketing_customer_analysis.xlsx' ,engine='openpyxl')

# %% [markdown]
# ### Dataframe shape

# %%
df.shape
# Out:
# (10910, 26)

# %% [markdown]
# ### Standarize header names

# %%
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Response',
#  'Coverage',
#  'Education',
#  'Effective To Date',
#  'EmploymentStatus',
#  'Gender',
#  'Income',
#  'Location Code',
#  'Marital Status',
#  'Monthly Premium Auto',
#  'Months Since Last Claim',
#  'Months Since Policy Inception',
#  'Number of Open Complaints',
#  'Number of Policies',
#  'Policy Type',
#  'Policy',
#  'Renew Offer Type',
#  'Sales Channel',
#  'Total Claim Amount',
#  'Vehicle Class',
#  'Vehicle Size',
#  'Vehicle Type']

# %%
def standardize_col(col):
    return col.lower().replace(" ","_")

# %%
standardize_col('State')
# Out:
# 'state'

# %%
new_cols=[]
for col in df.columns.to_list():
    new_cols.append(standardize_col(col))

# %%
new_cols
# Out:
# ['unnamed:_0',
#  'customer',
#  'state',
#  'customer_lifetime_value',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'total_claim_amount',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
#overwrite new columns

df.columns=new_cols

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
df=df.rename(columns={"unnamed:_0":"unnamed"})

# %%
df=df.rename(columns={"EmploymentStatus":"Employment_Status"})

# %%
df.head()
# Out:
#    unnamed customer       state  customer_lifetime_value response  coverage  \
# 0        0  DK49336     Arizona              4809.216960       No     Basic
# 1        1  KX64629  California              2228.525238       No     Basic
# 2        2  LZ68649  Washington             14947.917300       No     Basic
# 3        3  XL78013      Oregon             22332.439460      Yes  Extended
# 4        4  QA50777      Oregon              9025.067525       No   Premium
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
# 2  Bachelor        2011-02-10         Employed      M  ...
# 3   College        2011-01-11         Employed      M  ...
# 4  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Which columns are numerical?

# %%
df.select_dtypes(np.number)
# Out:
#        unnamed  customer_lifetime_value  income  monthly_premium_auto  \
# 0            0              4809.216960   48029                    61
# 1            1              2228.525238       0                    64
# 2            2             14947.917300   22139                   100
# 3            3             22332.439460   49078                    97
# 4            4              9025.067525   23675                   117
# ...        ...                      ...     ...                   ...
# 10905    10905             15563.369440       0                   253
# 10906    10906              5259.444853   61146                    65
# 10907    10907             23893.304100   39837                   201
# 10908    10908             11971.977650   64195                   158
# 10909    10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                            0.0                   9          292.800000
# 1                            0.0                   1          744.924331
# 2                            0.0                   2          480.000000
# 3                            0.0                   2          484.013411
# 4                            NaN                   7          707.925645
# ...                          ...                 ...                 ...
# 10905                        NaN                   7         1214.400000
# 10906                        0.0                   6          273.018929
# 10907                        0.0                   2          381.306996
# 10908                        4.0                   6          618.288849
# 10909                        0.0                   3         1021.719397
#
# [10910 rows x 9 columns]

# %%
df_numerical=df._get_numeric_data()

# %%
df_numerical
# Out:
#        unnamed  customer_lifetime_value  income  monthly_premium_auto  \
# 0            0              4809.216960   48029                    61
# 1            1              2228.525238       0                    64
# 2            2             14947.917300   22139                   100
# 3            3             22332.439460   49078                    97
# 4            4              9025.067525   23675                   117
# ...        ...                      ...     ...                   ...
# 10905    10905             15563.369440       0                   253
# 10906    10906              5259.444853   61146                    65
# 10907    10907             23893.304100   39837                   201
# 10908    10908             11971.977650   64195                   158
# 10909    10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                            0.0                   9          292.800000
# 1                            0.0                   1          744.924331
# 2                            0.0                   2          480.000000
# 3                            0.0                   2          484.013411
# 4                            NaN                   7          707.925645
# ...                          ...                 ...                 ...
# 10905                        NaN                   7         1214.400000
# 10906                        0.0                   6          273.018929
# 10907                        0.0                   2          381.306996
# 10908                        4.0                   6          618.288849
# 10909                        0.0                   3         1021.719397
#
# [10910 rows x 9 columns]

# %% [markdown]
# ### Which columns are categorical?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed                        10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
#  12  marital_status                 10910 non-null  object
#  13  monthly_premium_auto           10910 non-null  int64
#  14  months_since_last_claim        10277 non-null  float64
#  15  months_since_policy_inception  10910 non-null  int64
#  16  number_of_open_complaints      10277 non-null  float64
#  17  number_of_policies             10910 non-null  int64
#  18  policy_type                    10910 non-null  object
#  19  policy                         10910 non-null  object
#  20  renew_offer_type               10910 non-null  object
#  21  sales_channel                  10910 non-null  object
#  22  total_claim_amount             10910 non-null  float64
#  23  vehicle_class                  10288 non-null  object
#  24  vehicle_size                   10288 non-null  object
#  25  vehicle_type                   5428 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(16)
# memory usage: 2.2+ MB

# %%
df.select_dtypes(include='object')
# Out:
#       customer       state response  coverage education employmentstatus  \
# 0      DK49336     Arizona       No     Basic   College         Employed
# 1      KX64629  California       No     Basic   College       Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor         Employed
# 3      XL78013      Oregon      Yes  Extended   College         Employed
# 4      QA50777      Oregon       No   Premium  Bachelor    Medical Leave
# ...        ...         ...      ...       ...       ...              ...
# 10905  FE99816      Nevada       No   Premium  Bachelor       Unemployed
# 10906  KX53892      Oregon       No     Basic   College         Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor         Employed
# 10908  WA60547  California       No   Premium   College         Employed
# 10909  IV32877         NaN      NaN     Basic  Bachelor       Unemployed
#
#       gender location_code marital_status     policy_type        policy  \
# 0          M      Suburban        Married  Corporate Auto  Corporate L3
# 1          F      Suburban         Single   Personal Auto   Personal L3
# 2          M      Suburban         Single   Personal Auto   Personal L3
# 3          M      Suburban         Single  Corporate Auto  Corporate L3
# 4          F      Suburban        Married   Personal Auto   Personal L2
# ...      ...           ...            ...             ...           ...
# 10905      F      Suburban        Married   Personal Auto   Personal L1
# 10906      F         Urban        Married   Personal Auto   Personal L3
# 10907      F         Rural        Married  Corporate Auto  Corporate L3
# 10908      F         Urban       Divorced   Personal Auto   Personal L1
# 10909      M      Suburban         Single   Personal Auto   Personal L1
#
#       renew_offer_type sales_channel  vehicle_class vehicle_size vehicle_type
# 0               Offer3         Agent  Four-Door Car      Medsize          NaN
# 1               Offer4   Call Center  Four-Door Car      Medsize          NaN
# 2               Offer3   Call Center            SUV      Medsize            A
# 3               Offer2        Branch  Four-Door Car      Medsize            A
# 4               Offer1        Branch  Four-Door Car      Medsize          NaN
# ...                ...           ...            ...          ...          ...
# 10905           Offer3           Web     Luxury Car      Medsize            A
# 10906           Offer2        Branch  Four-Door Car      Medsize            A
# 10907           Offer1           Web     Luxury SUV      Medsize          NaN
# 10908           Offer1        Branch            SUV      Medsize            A
# 10909           Offer4           Web            SUV      Medsize          NaN
#
# [10910 rows x 16 columns]

# %%
df.categorical=df.select_dtypes(include='object')

# %%
df.categorical
# Out:
#       customer       state response  coverage education employmentstatus  \
# 0      DK49336     Arizona       No     Basic   College         Employed
# 1      KX64629  California       No     Basic   College       Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor         Employed
# 3      XL78013      Oregon      Yes  Extended   College         Employed
# 4      QA50777      Oregon       No   Premium  Bachelor    Medical Leave
# ...        ...         ...      ...       ...       ...              ...
# 10905  FE99816      Nevada       No   Premium  Bachelor       Unemployed
# 10906  KX53892      Oregon       No     Basic   College         Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor         Employed
# 10908  WA60547  California       No   Premium   College         Employed
# 10909  IV32877         NaN      NaN     Basic  Bachelor       Unemployed
#
#       gender location_code marital_status     policy_type        policy  \
# 0          M      Suburban        Married  Corporate Auto  Corporate L3
# 1          F      Suburban         Single   Personal Auto   Personal L3
# 2          M      Suburban         Single   Personal Auto   Personal L3
# 3          M      Suburban         Single  Corporate Auto  Corporate L3
# 4          F      Suburban        Married   Personal Auto   Personal L2
# ...      ...           ...            ...             ...           ...
# 10905      F      Suburban        Married   Personal Auto   Personal L1
# 10906      F         Urban        Married   Personal Auto   Personal L3
# 10907      F         Rural        Married  Corporate Auto  Corporate L3
# 10908      F         Urban       Divorced   Personal Auto   Personal L1
# 10909      M      Suburban         Single   Personal Auto   Personal L1
#
#       renew_offer_type sales_channel  vehicle_class vehicle_size vehicle_type
# 0               Offer3         Agent  Four-Door Car      Medsize          NaN
# 1               Offer4   Call Center  Four-Door Car      Medsize          NaN
# 2               Offer3   Call Center            SUV      Medsize            A
# 3               Offer2        Branch  Four-Door Car      Medsize            A
# 4               Offer1        Branch  Four-Door Car      Medsize          NaN
# ...                ...           ...            ...          ...          ...
# 10905           Offer3           Web     Luxury Car      Medsize            A
# 10906           Offer2        Branch  Four-Door Car      Medsize            A
# 10907           Offer1           Web     Luxury SUV      Medsize          NaN
# 10908           Offer1        Branch            SUV      Medsize            A
# 10909           Offer4           Web            SUV      Medsize          NaN
#
# [10910 rows x 16 columns]

# %% [markdown]
# ### Check and deal with NaN values.

# %%
df.isna().all(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10905    False
# 10906    False
# 10907    False
# 10908    False
# 10909    False
# Length: 10910, dtype: bool

# %%
nullsdf=pd.DataFrame(round(df.isna().sum()/len(df),4)*100)

# %%
nullsdf=nullsdf.rename(columns={'index':'header',0:'proportionnulls'})

# %%
nullsdf
# Out:
#                                proportionnulls
# unnamed                                   0.00
# customer                                  0.00
# state                                     5.78
# customer_lifetime_value                   0.00
# response                                  5.78
# coverage                                  0.00
# education                                 0.00
# effective_to_date                         0.00
# employmentstatus                          0.00
# gender                                    0.00
# income                                    0.00
# location_code                             0.00
# marital_status                            0.00
# monthly_premium_auto                      0.00
# months_since_last_claim                   5.80
# months_since_policy_inception             0.00
# number_of_open_complaints                 5.80
# number_of_policies                        0.00
# policy_type                               0.00
# policy                                    0.00
# renew_offer_type                          0.00
# sales_channel                             0.00
# total_claim_amount                        0.00
# vehicle_class                             5.70
# vehicle_size                              5.70
# vehicle_type                             50.25

# %% [markdown]
# ### categorical nulls 1st - state, response, vehicle class,vehicle size,vehicle type

# %%
df[df['state'].isna()==True]
# Out:
#        unnamed customer state  customer_lifetime_value response  coverage  \
# 5            5  HO81102   NaN              4745.181764      NaN     Basic
# 11          11  GE63585   NaN              2420.711888      NaN     Basic
# 58          58  BR69566   NaN             14019.833140      NaN     Basic
# 62          62  UF44021   NaN              2108.493744      NaN     Basic
# 126        126  TE60343   NaN              4716.264294      NaN     Basic
# ...        ...      ...   ...                      ...      ...       ...
# 10837    10837  IJ40048   NaN              4978.950257      NaN     Basic
# 10849    10849  SO38188   NaN              5308.617246      NaN  Extended
# 10874    10874  PD52748   NaN             10036.536340      NaN  Extended
# 10894    10894  EX63393   NaN              6314.492009      NaN  Extended
# 10909    10909  IV32877   NaN              6857.519928      NaN     Basic
#
#                   education effective_to_date employmentstatus gender  ...  \
# 5      High School or Below        2011-02-14         Employed      M  ...
# 11                 Bachelor        2011-02-07         Employed      M  ...
# 58                  College        2011-02-18         Employed      M  ...
# 62                 Bachelor        2011-01-02       Unemployed      M  ...
# 126    High School or Below        2011-02-25         Employed      M  ...
# ...                     ...               ...              ...    ...  ...
# 10837              Bachelor        2011-01-31         Employed      M  ...
# 10849              Bachelor        2011-01-24         Employed      M  ...
# 10874  High School or Below        2011-02-12       Unemployed      F  ...
# 10894                Master        2011-02-27         Employed      F  ...
# 10909              Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 5                            0.0                  7   Personal Auto
# 11                           0.0                  1  Corporate Auto
# 58                           0.0                  2   Personal Auto
# 62                           0.0                  1   Personal Auto
# 126                          1.0                  3  Corporate Auto
# ...                          ...                ...             ...
# 10837                        0.0                  4  Corporate Auto
# 10849                        0.0                  1    Special Auto
# 10874                        1.0                  8   Personal Auto
# 10894                        0.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 5       Personal L3            Offer1          Agent          292.800000
# 11     Corporate L3            Offer1    Call Center          199.551735
# 58      Personal L3            Offer4    Call Center          469.882367
# 62      Personal L2            Offer1          Agent          351.856810
# 126    Corporate L3            Offer2          Agent          292.800000
# ...             ...               ...            ...                 ...
# 10837  Corporate L2            Offer1         Branch          221.241837
# 10849    Special L2            Offer1          Agent          652.800000
# 10874   Personal L3            Offer1    Call Center         1353.289060
# 10894   Personal L1            Offer3          Agent          374.400000
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 5      Four-Door Car      Medsize            A
# 11      Two-Door Car      Medsize          NaN
# 58      Two-Door Car        Small          NaN
# 62      Two-Door Car      Medsize          NaN
# 126    Four-Door Car      Medsize            A
# ...              ...          ...          ...
# 10837  Four-Door Car      Medsize            A
# 10849            SUV      Medsize          NaN
# 10874            SUV      Medsize          NaN
# 10894  Four-Door Car        Small          NaN
# 10909            SUV      Medsize          NaN
#
# [631 rows x 26 columns]

# %%
df['state']=df['state'].fillna('Unknown')

# %%
df[df['state']=='Unknown']
# Out:
#        unnamed customer    state  customer_lifetime_value response  coverage  \
# 5            5  HO81102  Unknown              4745.181764      NaN     Basic
# 11          11  GE63585  Unknown              2420.711888      NaN     Basic
# 58          58  BR69566  Unknown             14019.833140      NaN     Basic
# 62          62  UF44021  Unknown              2108.493744      NaN     Basic
# 126        126  TE60343  Unknown              4716.264294      NaN     Basic
# ...        ...      ...      ...                      ...      ...       ...
# 10837    10837  IJ40048  Unknown              4978.950257      NaN     Basic
# 10849    10849  SO38188  Unknown              5308.617246      NaN  Extended
# 10874    10874  PD52748  Unknown             10036.536340      NaN  Extended
# 10894    10894  EX63393  Unknown              6314.492009      NaN  Extended
# 10909    10909  IV32877  Unknown              6857.519928      NaN     Basic
#
#                   education effective_to_date employmentstatus gender  ...  \
# 5      High School or Below        2011-02-14         Employed      M  ...
# 11                 Bachelor        2011-02-07         Employed      M  ...
# 58                  College        2011-02-18         Employed      M  ...
# 62                 Bachelor        2011-01-02       Unemployed      M  ...
# 126    High School or Below        2011-02-25         Employed      M  ...
# ...                     ...               ...              ...    ...  ...
# 10837              Bachelor        2011-01-31         Employed      M  ...
# 10849              Bachelor        2011-01-24         Employed      M  ...
# 10874  High School or Below        2011-02-12       Unemployed      F  ...
# 10894                Master        2011-02-27         Employed      F  ...
# 10909              Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 5                            0.0                  7   Personal Auto
# 11                           0.0                  1  Corporate Auto
# 58                           0.0                  2   Personal Auto
# 62                           0.0                  1   Personal Auto
# 126                          1.0                  3  Corporate Auto
# ...                          ...                ...             ...
# 10837                        0.0                  4  Corporate Auto
# 10849                        0.0                  1    Special Auto
# 10874                        1.0                  8   Personal Auto
# 10894                        0.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 5       Personal L3            Offer1          Agent          292.800000
# 11     Corporate L3            Offer1    Call Center          199.551735
# 58      Personal L3            Offer4    Call Center          469.882367
# 62      Personal L2            Offer1          Agent          351.856810
# 126    Corporate L3            Offer2          Agent          292.800000
# ...             ...               ...            ...                 ...
# 10837  Corporate L2            Offer1         Branch          221.241837
# 10849    Special L2            Offer1          Agent          652.800000
# 10874   Personal L3            Offer1    Call Center         1353.289060
# 10894   Personal L1            Offer3          Agent          374.400000
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 5      Four-Door Car      Medsize            A
# 11      Two-Door Car      Medsize          NaN
# 58      Two-Door Car        Small          NaN
# 62      Two-Door Car      Medsize          NaN
# 126    Four-Door Car      Medsize            A
# ...              ...          ...          ...
# 10837  Four-Door Car      Medsize            A
# 10849            SUV      Medsize          NaN
# 10874            SUV      Medsize          NaN
# 10894  Four-Door Car        Small          NaN
# 10909            SUV      Medsize          NaN
#
# [631 rows x 26 columns]

# %%
df[df['response'].isna()==True]
# Out:
#        unnamed customer    state  customer_lifetime_value response  coverage  \
# 5            5  HO81102  Unknown              4745.181764      NaN     Basic
# 11          11  GE63585  Unknown              2420.711888      NaN     Basic
# 58          58  BR69566  Unknown             14019.833140      NaN     Basic
# 62          62  UF44021  Unknown              2108.493744      NaN     Basic
# 126        126  TE60343  Unknown              4716.264294      NaN     Basic
# ...        ...      ...      ...                      ...      ...       ...
# 10837    10837  IJ40048  Unknown              4978.950257      NaN     Basic
# 10849    10849  SO38188  Unknown              5308.617246      NaN  Extended
# 10874    10874  PD52748  Unknown             10036.536340      NaN  Extended
# 10894    10894  EX63393  Unknown              6314.492009      NaN  Extended
# 10909    10909  IV32877  Unknown              6857.519928      NaN     Basic
#
#                   education effective_to_date employmentstatus gender  ...  \
# 5      High School or Below        2011-02-14         Employed      M  ...
# 11                 Bachelor        2011-02-07         Employed      M  ...
# 58                  College        2011-02-18         Employed      M  ...
# 62                 Bachelor        2011-01-02       Unemployed      M  ...
# 126    High School or Below        2011-02-25         Employed      M  ...
# ...                     ...               ...              ...    ...  ...
# 10837              Bachelor        2011-01-31         Employed      M  ...
# 10849              Bachelor        2011-01-24         Employed      M  ...
# 10874  High School or Below        2011-02-12       Unemployed      F  ...
# 10894                Master        2011-02-27         Employed      F  ...
# 10909              Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_open_complaints number_of_policies     policy_type  \
# 5                            0.0                  7   Personal Auto
# 11                           0.0                  1  Corporate Auto
# 58                           0.0                  2   Personal Auto
# 62                           0.0                  1   Personal Auto
# 126                          1.0                  3  Corporate Auto
# ...                          ...                ...             ...
# 10837                        0.0                  4  Corporate Auto
# 10849                        0.0                  1    Special Auto
# 10874                        1.0                  8   Personal Auto
# 10894                        0.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 5       Personal L3            Offer1          Agent          292.800000
# 11     Corporate L3            Offer1    Call Center          199.551735
# 58      Personal L3            Offer4    Call Center          469.882367
# 62      Personal L2            Offer1          Agent          351.856810
# 126    Corporate L3            Offer2          Agent          292.800000
# ...             ...               ...            ...                 ...
# 10837  Corporate L2            Offer1         Branch          221.241837
# 10849    Special L2            Offer1          Agent          652.800000
# 10874   Personal L3            Offer1    Call Center         1353.289060
# 10894   Personal L1            Offer3          Agent          374.400000
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 5      Four-Door Car      Medsize            A
# 11      Two-Door Car      Medsize          NaN
# 58      Two-Door Car        Small          NaN
# 62      Two-Door Car      Medsize          NaN
# 126    Four-Door Car      Medsize            A
# ...              ...          ...          ...
# 10837  Four-Door Car      Medsize            A
# 10849            SUV      Medsize          NaN
# 10874            SUV      Medsize          NaN
# 10894  Four-Door Car        Small          NaN
# 10909            SUV      Medsize          NaN
#
# [631 rows x 26 columns]

# %%
df['response']=df['response'].fillna('No response')

# %%
df[df['response']=='No response']
# Out:
#        unnamed customer    state  customer_lifetime_value     response  \
# 5            5  HO81102  Unknown              4745.181764  No response
# 11          11  GE63585  Unknown              2420.711888  No response
# 58          58  BR69566  Unknown             14019.833140  No response
# 62          62  UF44021  Unknown              2108.493744  No response
# 126        126  TE60343  Unknown              4716.264294  No response
# ...        ...      ...      ...                      ...          ...
# 10837    10837  IJ40048  Unknown              4978.950257  No response
# 10849    10849  SO38188  Unknown              5308.617246  No response
# 10874    10874  PD52748  Unknown             10036.536340  No response
# 10894    10894  EX63393  Unknown              6314.492009  No response
# 10909    10909  IV32877  Unknown              6857.519928  No response
#
#        coverage             education effective_to_date employmentstatus  \
# 5         Basic  High School or Below        2011-02-14         Employed
# 11        Basic              Bachelor        2011-02-07         Employed
# 58        Basic               College        2011-02-18         Employed
# 62        Basic              Bachelor        2011-01-02       Unemployed
# 126       Basic  High School or Below        2011-02-25         Employed
# ...         ...                   ...               ...              ...
# 10837     Basic              Bachelor        2011-01-31         Employed
# 10849  Extended              Bachelor        2011-01-24         Employed
# 10874  Extended  High School or Below        2011-02-12       Unemployed
# 10894  Extended                Master        2011-02-27         Employed
# 10909     Basic              Bachelor        2011-01-08       Unemployed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 5          M  ...                        0.0                  7
# 11         M  ...                        0.0                  1
# 58         M  ...                        0.0                  2
# 62         M  ...                        0.0                  1
# 126        M  ...                        1.0                  3
# ...      ...  ...                        ...                ...
# 10837      M  ...                        0.0                  4
# 10849      M  ...                        0.0                  1
# 10874      F  ...                        1.0                  8
# 10894      F  ...                        0.0                  6
# 10909      M  ...                        0.0                  3
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 5       Personal Auto   Personal L3            Offer1          Agent
# 11     Corporate Auto  Corporate L3            Offer1    Call Center
# 58      Personal Auto   Personal L3            Offer4    Call Center
# 62      Personal Auto   Personal L2            Offer1          Agent
# 126    Corporate Auto  Corporate L3            Offer2          Agent
# ...               ...           ...               ...            ...
# 10837  Corporate Auto  Corporate L2            Offer1         Branch
# 10849    Special Auto    Special L2            Offer1          Agent
# 10874   Personal Auto   Personal L3            Offer1    Call Center
# 10894   Personal Auto   Personal L1            Offer3          Agent
# 10909   Personal Auto   Personal L1            Offer4            Web
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 5              292.800000  Four-Door Car      Medsize            A
# 11             199.551735   Two-Door Car      Medsize          NaN
# 58             469.882367   Two-Door Car        Small          NaN
# 62             351.856810   Two-Door Car      Medsize          NaN
# 126            292.800000  Four-Door Car      Medsize            A
# ...                   ...            ...          ...          ...
# 10837          221.241837  Four-Door Car      Medsize            A
# 10849          652.800000            SUV      Medsize          NaN
# 10874         1353.289060            SUV      Medsize          NaN
# 10894          374.400000  Four-Door Car        Small          NaN
# 10909         1021.719397            SUV      Medsize          NaN
#
# [631 rows x 26 columns]

# %%
df[df['vehicle_class'].isna()==True]
# Out:
#        unnamed customer       state  customer_lifetime_value response  \
# 87          87  ZH92587      Oregon              8126.766397       No
# 88          88  CJ51511     Arizona             13466.920710      Yes
# 89          89  ME37450     Arizona              5210.348372       No
# 97          97  CA22248      Oregon              2505.420430       No
# 148        148  HB24005  California              2347.048112       No
# ...        ...      ...         ...                      ...      ...
# 10852    10852  KZ80424  Washington              8382.478392      Yes
# 10860    10860  GA79817     Arizona              2369.111588       No
# 10879    10879  FK95213  California             18611.453560       No
# 10883    10883  FD64348      Oregon             22563.618380       No
# 10890    10890  VQ78876      Oregon              4660.399573       No
#
#        coverage             education effective_to_date employmentstatus  \
# 87        Basic               College        2011-02-22         Disabled
# 88        Basic  High School or Below        2011-02-23         Disabled
# 89        Basic              Bachelor        2011-01-04         Employed
# 97        Basic                Master        2011-02-14         Employed
# 148       Basic               College        2011-02-02         Employed
# ...         ...                   ...               ...              ...
# 10852     Basic              Bachelor        2011-01-27         Employed
# 10860     Basic              Bachelor        2011-02-05       Unemployed
# 10879  Extended                Master        2011-01-16         Employed
# 10883     Basic  High School or Below        2011-01-17         Employed
# 10890     Basic              Bachelor        2011-02-03         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 87         F  ...                        NaN                  3
# 88         F  ...                        NaN                  2
# 89         M  ...                        0.0                  5
# 97         F  ...                        0.0                  1
# 148        M  ...                        1.0                  1
# ...      ...  ...                        ...                ...
# 10852      M  ...                        0.0                  2
# 10860      M  ...                        0.0                  1
# 10879      F  ...                        0.0                  7
# 10883      M  ...                        3.0                  2
# 10890      F  ...                        0.0                  1
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 87      Personal Auto   Personal L3            Offer1          Agent
# 88     Corporate Auto  Corporate L3            Offer2          Agent
# 89       Special Auto    Special L2            Offer1          Agent
# 97      Personal Auto   Personal L3            Offer2         Branch
# 148     Personal Auto   Personal L1            Offer1          Agent
# ...               ...           ...               ...            ...
# 10852   Personal Auto   Personal L2            Offer2    Call Center
# 10860  Corporate Auto  Corporate L2            Offer3    Call Center
# 10879   Personal Auto   Personal L3            Offer2            Web
# 10883   Personal Auto   Personal L3            Offer4         Branch
# 10890  Corporate Auto  Corporate L3            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 87             513.600000            NaN          NaN          NaN
# 88             571.200000            NaN          NaN          NaN
# 89              37.960537            NaN          NaN            A
# 97              46.278027            NaN          NaN            A
# 148            244.269407            NaN          NaN            A
# ...                   ...            ...          ...          ...
# 10852          791.878042            NaN          NaN            A
# 10860          468.000000            NaN          NaN          NaN
# 10879         1021.654003            NaN          NaN          NaN
# 10883            1.687291            NaN          NaN            A
# 10890           43.155950            NaN          NaN          NaN
#
# [622 rows x 26 columns]

# %%
df['vehicle_class']=df['vehicle_class'].fillna('Unknown')

# %%
df[df['vehicle_class']=='Unknown']
# Out:
#        unnamed customer       state  customer_lifetime_value response  \
# 87          87  ZH92587      Oregon              8126.766397       No
# 88          88  CJ51511     Arizona             13466.920710      Yes
# 89          89  ME37450     Arizona              5210.348372       No
# 97          97  CA22248      Oregon              2505.420430       No
# 148        148  HB24005  California              2347.048112       No
# ...        ...      ...         ...                      ...      ...
# 10852    10852  KZ80424  Washington              8382.478392      Yes
# 10860    10860  GA79817     Arizona              2369.111588       No
# 10879    10879  FK95213  California             18611.453560       No
# 10883    10883  FD64348      Oregon             22563.618380       No
# 10890    10890  VQ78876      Oregon              4660.399573       No
#
#        coverage             education effective_to_date employmentstatus  \
# 87        Basic               College        2011-02-22         Disabled
# 88        Basic  High School or Below        2011-02-23         Disabled
# 89        Basic              Bachelor        2011-01-04         Employed
# 97        Basic                Master        2011-02-14         Employed
# 148       Basic               College        2011-02-02         Employed
# ...         ...                   ...               ...              ...
# 10852     Basic              Bachelor        2011-01-27         Employed
# 10860     Basic              Bachelor        2011-02-05       Unemployed
# 10879  Extended                Master        2011-01-16         Employed
# 10883     Basic  High School or Below        2011-01-17         Employed
# 10890     Basic              Bachelor        2011-02-03         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 87         F  ...                        NaN                  3
# 88         F  ...                        NaN                  2
# 89         M  ...                        0.0                  5
# 97         F  ...                        0.0                  1
# 148        M  ...                        1.0                  1
# ...      ...  ...                        ...                ...
# 10852      M  ...                        0.0                  2
# 10860      M  ...                        0.0                  1
# 10879      F  ...                        0.0                  7
# 10883      M  ...                        3.0                  2
# 10890      F  ...                        0.0                  1
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 87      Personal Auto   Personal L3            Offer1          Agent
# 88     Corporate Auto  Corporate L3            Offer2          Agent
# 89       Special Auto    Special L2            Offer1          Agent
# 97      Personal Auto   Personal L3            Offer2         Branch
# 148     Personal Auto   Personal L1            Offer1          Agent
# ...               ...           ...               ...            ...
# 10852   Personal Auto   Personal L2            Offer2    Call Center
# 10860  Corporate Auto  Corporate L2            Offer3    Call Center
# 10879   Personal Auto   Personal L3            Offer2            Web
# 10883   Personal Auto   Personal L3            Offer4         Branch
# 10890  Corporate Auto  Corporate L3            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 87             513.600000        Unknown          NaN          NaN
# 88             571.200000        Unknown          NaN          NaN
# 89              37.960537        Unknown          NaN            A
# 97              46.278027        Unknown          NaN            A
# 148            244.269407        Unknown          NaN            A
# ...                   ...            ...          ...          ...
# 10852          791.878042        Unknown          NaN            A
# 10860          468.000000        Unknown          NaN          NaN
# 10879         1021.654003        Unknown          NaN          NaN
# 10883            1.687291        Unknown          NaN            A
# 10890           43.155950        Unknown          NaN          NaN
#
# [622 rows x 26 columns]

# %%
df[df['vehicle_type'].isna()==True]
# Out:
#        unnamed customer       state  customer_lifetime_value     response  \
# 0            0  DK49336     Arizona              4809.216960           No
# 1            1  KX64629  California              2228.525238           No
# 4            4  QA50777      Oregon              9025.067525           No
# 6            6  IW72280  California              5035.035257           No
# 7            7  IH64929  California              4956.247235           No
# ...        ...      ...         ...                      ...          ...
# 10898    10898  SO95845  California              5807.659307           No
# 10900    10900  VN73653      Oregon              6423.739052           No
# 10901    10901  RY92254  Washington              4547.892543           No
# 10907    10907  TL39050     Arizona             23893.304100           No
# 10909    10909  IV32877     Unknown              6857.519928  No response
#
#        coverage             education effective_to_date employmentstatus  \
# 0         Basic               College        2011-02-18         Employed
# 1         Basic               College        2011-01-18       Unemployed
# 4       Premium              Bachelor        2011-01-17    Medical Leave
# 6         Basic                Doctor        2011-02-14         Employed
# 7         Basic  High School or Below        2011-02-24         Employed
# ...         ...                   ...               ...              ...
# 10898     Basic               College        2011-01-07         Employed
# 10900     Basic               College        2011-02-13       Unemployed
# 10901   Premium              Bachelor        2011-01-13         Employed
# 10907  Extended              Bachelor        2011-02-06         Employed
# 10909     Basic              Bachelor        2011-01-08       Unemployed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 0          M  ...                        0.0                  9
# 1          F  ...                        0.0                  1
# 4          F  ...                        NaN                  7
# 6          F  ...                        3.0                  4
# 7          M  ...                        0.0                  3
# ...      ...  ...                        ...                ...
# 10898      F  ...                        0.0                  7
# 10900      M  ...                        0.0                  1
# 10901      M  ...                        0.0                  1
# 10907      F  ...                        0.0                  2
# 10909      M  ...                        0.0                  3
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 0      Corporate Auto  Corporate L3            Offer3          Agent
# 1       Personal Auto   Personal L3            Offer4    Call Center
# 4       Personal Auto   Personal L2            Offer1         Branch
# 6      Corporate Auto  Corporate L2            Offer2         Branch
# 7       Personal Auto   Personal L2            Offer2         Branch
# ...               ...           ...               ...            ...
# 10898   Personal Auto   Personal L3            Offer4    Call Center
# 10900  Corporate Auto  Corporate L2            Offer3          Agent
# 10901   Personal Auto   Personal L3            Offer4          Agent
# 10907  Corporate Auto  Corporate L3            Offer1            Web
# 10909   Personal Auto   Personal L1            Offer4            Web
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 0              292.800000  Four-Door Car      Medsize          NaN
# 1              744.924331  Four-Door Car      Medsize          NaN
# 4              707.925645  Four-Door Car      Medsize          NaN
# 6              287.556107  Four-Door Car      Medsize          NaN
# 7              247.402353   Two-Door Car      Medsize          NaN
# ...                   ...            ...          ...          ...
# 10898          133.977857   Two-Door Car      Medsize          NaN
# 10900         1621.560425     Luxury SUV      Medsize          NaN
# 10901          801.577478   Two-Door Car      Medsize          NaN
# 10907          381.306996     Luxury SUV      Medsize          NaN
# 10909         1021.719397            SUV      Medsize          NaN
#
# [5482 rows x 26 columns]

# %%
df['vehicle_type']=df['vehicle_type'].fillna('Unknown')

# %%
df[df['vehicle_type']=='Unknown']
# Out:
#        unnamed customer       state  customer_lifetime_value     response  \
# 0            0  DK49336     Arizona              4809.216960           No
# 1            1  KX64629  California              2228.525238           No
# 4            4  QA50777      Oregon              9025.067525           No
# 6            6  IW72280  California              5035.035257           No
# 7            7  IH64929  California              4956.247235           No
# ...        ...      ...         ...                      ...          ...
# 10898    10898  SO95845  California              5807.659307           No
# 10900    10900  VN73653      Oregon              6423.739052           No
# 10901    10901  RY92254  Washington              4547.892543           No
# 10907    10907  TL39050     Arizona             23893.304100           No
# 10909    10909  IV32877     Unknown              6857.519928  No response
#
#        coverage             education effective_to_date employmentstatus  \
# 0         Basic               College        2011-02-18         Employed
# 1         Basic               College        2011-01-18       Unemployed
# 4       Premium              Bachelor        2011-01-17    Medical Leave
# 6         Basic                Doctor        2011-02-14         Employed
# 7         Basic  High School or Below        2011-02-24         Employed
# ...         ...                   ...               ...              ...
# 10898     Basic               College        2011-01-07         Employed
# 10900     Basic               College        2011-02-13       Unemployed
# 10901   Premium              Bachelor        2011-01-13         Employed
# 10907  Extended              Bachelor        2011-02-06         Employed
# 10909     Basic              Bachelor        2011-01-08       Unemployed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 0          M  ...                        0.0                  9
# 1          F  ...                        0.0                  1
# 4          F  ...                        NaN                  7
# 6          F  ...                        3.0                  4
# 7          M  ...                        0.0                  3
# ...      ...  ...                        ...                ...
# 10898      F  ...                        0.0                  7
# 10900      M  ...                        0.0                  1
# 10901      M  ...                        0.0                  1
# 10907      F  ...                        0.0                  2
# 10909      M  ...                        0.0                  3
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 0      Corporate Auto  Corporate L3            Offer3          Agent
# 1       Personal Auto   Personal L3            Offer4    Call Center
# 4       Personal Auto   Personal L2            Offer1         Branch
# 6      Corporate Auto  Corporate L2            Offer2         Branch
# 7       Personal Auto   Personal L2            Offer2         Branch
# ...               ...           ...               ...            ...
# 10898   Personal Auto   Personal L3            Offer4    Call Center
# 10900  Corporate Auto  Corporate L2            Offer3          Agent
# 10901   Personal Auto   Personal L3            Offer4          Agent
# 10907  Corporate Auto  Corporate L3            Offer1            Web
# 10909   Personal Auto   Personal L1            Offer4            Web
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 0              292.800000  Four-Door Car      Medsize      Unknown
# 1              744.924331  Four-Door Car      Medsize      Unknown
# 4              707.925645  Four-Door Car      Medsize      Unknown
# 6              287.556107  Four-Door Car      Medsize      Unknown
# 7              247.402353   Two-Door Car      Medsize      Unknown
# ...                   ...            ...          ...          ...
# 10898          133.977857   Two-Door Car      Medsize      Unknown
# 10900         1621.560425     Luxury SUV      Medsize      Unknown
# 10901          801.577478   Two-Door Car      Medsize      Unknown
# 10907          381.306996     Luxury SUV      Medsize      Unknown
# 10909         1021.719397            SUV      Medsize      Unknown
#
# [5482 rows x 26 columns]

# %%
df[df['vehicle_size'].isna()==True]
# Out:
#        unnamed customer       state  customer_lifetime_value response  \
# 87          87  ZH92587      Oregon              8126.766397       No
# 88          88  CJ51511     Arizona             13466.920710      Yes
# 89          89  ME37450     Arizona              5210.348372       No
# 97          97  CA22248      Oregon              2505.420430       No
# 148        148  HB24005  California              2347.048112       No
# ...        ...      ...         ...                      ...      ...
# 10852    10852  KZ80424  Washington              8382.478392      Yes
# 10860    10860  GA79817     Arizona              2369.111588       No
# 10879    10879  FK95213  California             18611.453560       No
# 10883    10883  FD64348      Oregon             22563.618380       No
# 10890    10890  VQ78876      Oregon              4660.399573       No
#
#        coverage             education effective_to_date employmentstatus  \
# 87        Basic               College        2011-02-22         Disabled
# 88        Basic  High School or Below        2011-02-23         Disabled
# 89        Basic              Bachelor        2011-01-04         Employed
# 97        Basic                Master        2011-02-14         Employed
# 148       Basic               College        2011-02-02         Employed
# ...         ...                   ...               ...              ...
# 10852     Basic              Bachelor        2011-01-27         Employed
# 10860     Basic              Bachelor        2011-02-05       Unemployed
# 10879  Extended                Master        2011-01-16         Employed
# 10883     Basic  High School or Below        2011-01-17         Employed
# 10890     Basic              Bachelor        2011-02-03         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 87         F  ...                        NaN                  3
# 88         F  ...                        NaN                  2
# 89         M  ...                        0.0                  5
# 97         F  ...                        0.0                  1
# 148        M  ...                        1.0                  1
# ...      ...  ...                        ...                ...
# 10852      M  ...                        0.0                  2
# 10860      M  ...                        0.0                  1
# 10879      F  ...                        0.0                  7
# 10883      M  ...                        3.0                  2
# 10890      F  ...                        0.0                  1
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 87      Personal Auto   Personal L3            Offer1          Agent
# 88     Corporate Auto  Corporate L3            Offer2          Agent
# 89       Special Auto    Special L2            Offer1          Agent
# 97      Personal Auto   Personal L3            Offer2         Branch
# 148     Personal Auto   Personal L1            Offer1          Agent
# ...               ...           ...               ...            ...
# 10852   Personal Auto   Personal L2            Offer2    Call Center
# 10860  Corporate Auto  Corporate L2            Offer3    Call Center
# 10879   Personal Auto   Personal L3            Offer2            Web
# 10883   Personal Auto   Personal L3            Offer4         Branch
# 10890  Corporate Auto  Corporate L3            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 87             513.600000        Unknown          NaN          NaN
# 88             571.200000        Unknown          NaN          NaN
# 89              37.960537        Unknown          NaN            A
# 97              46.278027        Unknown          NaN            A
# 148            244.269407        Unknown          NaN            A
# ...                   ...            ...          ...          ...
# 10852          791.878042        Unknown          NaN            A
# 10860          468.000000        Unknown          NaN          NaN
# 10879         1021.654003        Unknown          NaN          NaN
# 10883            1.687291        Unknown          NaN            A
# 10890           43.155950        Unknown          NaN          NaN
#
# [622 rows x 26 columns]

# %%
df['vehicle_size']=df['vehicle_size'].fillna('Unknown')

# %%
df[df['vehicle_size']=='Unknown']
# Out:
#        unnamed customer       state  customer_lifetime_value response  \
# 87          87  ZH92587      Oregon              8126.766397       No
# 88          88  CJ51511     Arizona             13466.920710      Yes
# 89          89  ME37450     Arizona              5210.348372       No
# 97          97  CA22248      Oregon              2505.420430       No
# 148        148  HB24005  California              2347.048112       No
# ...        ...      ...         ...                      ...      ...
# 10852    10852  KZ80424  Washington              8382.478392      Yes
# 10860    10860  GA79817     Arizona              2369.111588       No
# 10879    10879  FK95213  California             18611.453560       No
# 10883    10883  FD64348      Oregon             22563.618380       No
# 10890    10890  VQ78876      Oregon              4660.399573       No
#
#        coverage             education effective_to_date employmentstatus  \
# 87        Basic               College        2011-02-22         Disabled
# 88        Basic  High School or Below        2011-02-23         Disabled
# 89        Basic              Bachelor        2011-01-04         Employed
# 97        Basic                Master        2011-02-14         Employed
# 148       Basic               College        2011-02-02         Employed
# ...         ...                   ...               ...              ...
# 10852     Basic              Bachelor        2011-01-27         Employed
# 10860     Basic              Bachelor        2011-02-05       Unemployed
# 10879  Extended                Master        2011-01-16         Employed
# 10883     Basic  High School or Below        2011-01-17         Employed
# 10890     Basic              Bachelor        2011-02-03         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 87         F  ...                        NaN                  3
# 88         F  ...                        NaN                  2
# 89         M  ...                        0.0                  5
# 97         F  ...                        0.0                  1
# 148        M  ...                        1.0                  1
# ...      ...  ...                        ...                ...
# 10852      M  ...                        0.0                  2
# 10860      M  ...                        0.0                  1
# 10879      F  ...                        0.0                  7
# 10883      M  ...                        3.0                  2
# 10890      F  ...                        0.0                  1
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 87      Personal Auto   Personal L3            Offer1          Agent
# 88     Corporate Auto  Corporate L3            Offer2          Agent
# 89       Special Auto    Special L2            Offer1          Agent
# 97      Personal Auto   Personal L3            Offer2         Branch
# 148     Personal Auto   Personal L1            Offer1          Agent
# ...               ...           ...               ...            ...
# 10852   Personal Auto   Personal L2            Offer2    Call Center
# 10860  Corporate Auto  Corporate L2            Offer3    Call Center
# 10879   Personal Auto   Personal L3            Offer2            Web
# 10883   Personal Auto   Personal L3            Offer4         Branch
# 10890  Corporate Auto  Corporate L3            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 87             513.600000        Unknown      Unknown      Unknown
# 88             571.200000        Unknown      Unknown      Unknown
# 89              37.960537        Unknown      Unknown            A
# 97              46.278027        Unknown      Unknown            A
# 148            244.269407        Unknown      Unknown            A
# ...                   ...            ...          ...          ...
# 10852          791.878042        Unknown      Unknown            A
# 10860          468.000000        Unknown      Unknown      Unknown
# 10879         1021.654003        Unknown      Unknown      Unknown
# 10883            1.687291        Unknown      Unknown            A
# 10890           43.155950        Unknown      Unknown      Unknown
#
# [622 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed                        10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
#  12  marital_status                 10910 non-null  object
#  13  monthly_premium_auto           10910 non-null  int64
#  14  months_since_last_claim        10277 non-null  float64
#  15  months_since_policy_inception  10910 non-null  int64
#  16  number_of_open_complaints      10277 non-null  float64
#  17  number_of_policies             10910 non-null  int64
#  18  policy_type                    10910 non-null  object
#  19  policy                         10910 non-null  object
#  20  renew_offer_type               10910 non-null  object
#  21  sales_channel                  10910 non-null  object
#  22  total_claim_amount             10910 non-null  float64
#  23  vehicle_class                  10910 non-null  object
#  24  vehicle_size                   10910 non-null  object
#  25  vehicle_type                   10910 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(16)
# memory usage: 2.2+ MB

# %% [markdown]
# ### numerical nulls - months_since_last_claim and number_of_open_complaints

# %%
months_since_last_claim_mean=df["months_since_last_claim"].mean()

# %%
df['months_since_last_claim']=df['months_since_last_claim'].fillna(months_since_last_claim_mean)

# %%
number_of_open_complaints_mean=df["months_since_last_claim"].mean()

# %%
df['number_of_open_complaints']=df['number_of_open_complaints'].fillna(number_of_open_complaints_mean)

# %%
df.info() #no more nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed                        10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
#  12  marital_status                 10910 non-null  object
#  13  monthly_premium_auto           10910 non-null  int64
#  14  months_since_last_claim        10910 non-null  float64
#  15  months_since_policy_inception  10910 non-null  int64
#  16  number_of_open_complaints      10910 non-null  float64
#  17  number_of_policies             10910 non-null  int64
#  18  policy_type                    10910 non-null  object
#  19  policy                         10910 non-null  object
#  20  renew_offer_type               10910 non-null  object
#  21  sales_channel                  10910 non-null  object
#  22  total_claim_amount             10910 non-null  float64
#  23  vehicle_class                  10910 non-null  object
#  24  vehicle_size                   10910 non-null  object
#  25  vehicle_type                   10910 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(16)
# memory usage: 2.2+ MB

# %% [markdown]
# ### Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
df.head()
# Out:
#    unnamed customer       state  customer_lifetime_value response  coverage  \
# 0        0  DK49336     Arizona              4809.216960       No     Basic
# 1        1  KX64629  California              2228.525238       No     Basic
# 2        2  LZ68649  Washington             14947.917300       No     Basic
# 3        3  XL78013      Oregon             22332.439460      Yes  Extended
# 4        4  QA50777      Oregon              9025.067525       No   Premium
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
# 2  Bachelor        2011-02-10         Employed      M  ...
# 3   College        2011-01-11         Employed      M  ...
# 4  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                   0.000000                  9  Corporate Auto  Corporate L3
# 1                   0.000000                  1   Personal Auto   Personal L3
# 2                   0.000000                  2   Personal Auto   Personal L3
# 3                   0.000000                  2  Corporate Auto  Corporate L3
# 4                  15.149071                  7   Personal Auto   Personal L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize      Unknown
# 1      Medsize      Unknown
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize      Unknown
#
# [5 rows x 26 columns]

# %%
import time
from datetime import date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed                        10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
#  12  marital_status                 10910 non-null  object
#  13  monthly_premium_auto           10910 non-null  int64
#  14  months_since_last_claim        10910 non-null  float64
#  15  months_since_policy_inception  10910 non-null  int64
#  16  number_of_open_complaints      10910 non-null  float64
#  17  number_of_policies             10910 non-null  int64
#  18  policy_type                    10910 non-null  object
#  19  policy                         10910 non-null  object
#  20  renew_offer_type               10910 non-null  object
#  21  sales_channel                  10910 non-null  object
#  22  total_claim_amount             10910 non-null  float64
#  23  vehicle_class                  10910 non-null  object
#  24  vehicle_size                   10910 non-null  object
#  25  vehicle_type                   10910 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(16)
# memory usage: 2.2+ MB

# %%
df['state'].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', 'Unknown',
#        'Nevada'], dtype=object)

# %%
df['effective_to_date']=pd.to_datetime(df['effective_to_date'],errors='coerce')

# %%
df['month']=pd.DatetimeIndex(df['effective_to_date']).month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed                        10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  datetime64[ns]
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
#  12  marital_status                 10910 non-null  object
#  13  monthly_premium_auto           10910 non-null  int64
#  14  months_since_last_claim        10910 non-null  float64
#  15  months_since_policy_inception  10910 non-null  int64
#  16  number_of_open_complaints      10910 non-null  float64
#  17  number_of_policies             10910 non-null  int64
#  18  policy_type                    10910 non-null  object
#  19  policy                         10910 non-null  object
#  20  renew_offer_type               10910 non-null  object
#  21  sales_channel                  10910 non-null  object
#  22  total_claim_amount             10910 non-null  float64
#  23  vehicle_class                  10910 non-null  object
#  24  vehicle_size                   10910 non-null  object
#  25  vehicle_type                   10910 non-null  object
#  26  month                          10910 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(16)
# memory usage: 2.2+ MB

# %%
df['month']=df['effective_to_date'].dt.strftime('%b')

# %%
df.head()
# Out:
#    unnamed customer       state  customer_lifetime_value response  coverage  \
# 0        0  DK49336     Arizona              4809.216960       No     Basic
# 1        1  KX64629  California              2228.525238       No     Basic
# 2        2  LZ68649  Washington             14947.917300       No     Basic
# 3        3  XL78013      Oregon             22332.439460      Yes  Extended
# 4        4  QA50777      Oregon              9025.067525       No   Premium
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
# 2  Bachelor        2011-02-10         Employed      M  ...
# 3   College        2011-01-11         Employed      M  ...
# 4  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# 0                   9  Corporate Auto  Corporate L3            Offer3
# 1                   1   Personal Auto   Personal L3            Offer4
# 2                   2   Personal Auto   Personal L3            Offer3
# 3                   2  Corporate Auto  Corporate L3            Offer2
# 4                   7   Personal Auto   Personal L2            Offer1
#
#    sales_channel  total_claim_amount  vehicle_class  vehicle_size  \
# 0          Agent          292.800000  Four-Door Car       Medsize
# 1    Call Center          744.924331  Four-Door Car       Medsize
# 2    Call Center          480.000000            SUV       Medsize
# 3         Branch          484.013411  Four-Door Car       Medsize
# 4         Branch          707.925645  Four-Door Car       Medsize
#
#   vehicle_type month
# 0      Unknown   Feb
# 1      Unknown   Jan
# 2            A   Feb
# 3            A   Jan
# 4      Unknown   Jan
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (10910, 27)

# %%
filtered1=df.query('month=="Jan"or month=="Feb" or month=="Mar"')

# %%
filtered1
# Out:
#        unnamed customer       state  customer_lifetime_value     response  \
# 0            0  DK49336     Arizona              4809.216960           No
# 1            1  KX64629  California              2228.525238           No
# 2            2  LZ68649  Washington             14947.917300           No
# 3            3  XL78013      Oregon             22332.439460          Yes
# 4            4  QA50777      Oregon              9025.067525           No
# ...        ...      ...         ...                      ...          ...
# 10905    10905  FE99816      Nevada             15563.369440           No
# 10906    10906  KX53892      Oregon              5259.444853           No
# 10907    10907  TL39050     Arizona             23893.304100           No
# 10908    10908  WA60547  California             11971.977650           No
# 10909    10909  IV32877     Unknown              6857.519928  No response
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# 0         Basic   College        2011-02-18         Employed      M  ...
# 1         Basic   College        2011-01-18       Unemployed      F  ...
# 2         Basic  Bachelor        2011-02-10         Employed      M  ...
# 3      Extended   College        2011-01-11         Employed      M  ...
# 4       Premium  Bachelor        2011-01-17    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# 0                       9  Corporate Auto  Corporate L3            Offer3
# 1                       1   Personal Auto   Personal L3            Offer4
# 2                       2   Personal Auto   Personal L3            Offer3
# 3                       2  Corporate Auto  Corporate L3            Offer2
# 4                       7   Personal Auto   Personal L2            Offer1
# ...                   ...             ...           ...               ...
# 10905                   7   Personal Auto   Personal L1            Offer3
# 10906                   6   Personal Auto   Personal L3            Offer2
# 10907                   2  Corporate Auto  Corporate L3            Offer1
# 10908                   6   Personal Auto   Personal L1            Offer1
# 10909                   3   Personal Auto   Personal L1            Offer4
#
#        sales_channel  total_claim_amount  vehicle_class  vehicle_size  \
# 0              Agent          292.800000  Four-Door Car       Medsize
# 1        Call Center          744.924331  Four-Door Car       Medsize
# 2        Call Center          480.000000            SUV       Medsize
# 3             Branch          484.013411  Four-Door Car       Medsize
# 4             Branch          707.925645  Four-Door Car       Medsize
# ...              ...                 ...            ...           ...
# 10905            Web         1214.400000     Luxury Car       Medsize
# 10906         Branch          273.018929  Four-Door Car       Medsize
# 10907            Web          381.306996     Luxury SUV       Medsize
# 10908         Branch          618.288849            SUV       Medsize
# 10909            Web         1021.719397            SUV       Medsize
#
#       vehicle_type month
# 0          Unknown   Feb
# 1          Unknown   Jan
# 2                A   Feb
# 3                A   Jan
# 4          Unknown   Jan
# ...            ...   ...
# 10905            A   Jan
# 10906            A   Jan
# 10907      Unknown   Feb
# 10908            A   Feb
# 10909      Unknown   Jan
#
# [10910 rows x 27 columns]

# %%
filtered1.shape
# Out:
# (10910, 27)

# %% [markdown]
# ### BONUS: Put all the previously mentioned data transformations into a function.
