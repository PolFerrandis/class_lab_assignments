# %% [markdown]
# # Favourite Holiday Trip
# ## I will explain in this notebook what my favourite Holiday trip is

# %% [markdown]
# ### Index
#
# [ - Name](#heading-title1)
#
# [ - Picture](#heading-title2)
#
# [ - Holiday destination](#heading-title3)
#
# [ - Photo destination](#heading-title4)
#
# [ - Things to do](#heading-title5)
#
# [ - Video](#heading-title6)

# %% [markdown]
# ### Name<a id="heading-title1"></a>

# %%
name = input("Enter your first name: ")

# %% [markdown]
# ### Picture<a id="heading-title2"></a>

# %% [markdown]
# ![WhatsApp%20Image%202021-03-02%20at%2010.01.07.jpeg](attachment:WhatsApp%20Image%202021-03-02%20at%2010.01.07.jpeg)

# %% [markdown]
# ### Holiday destination<a id="heading-title3"></a>

# %%
fav_holiday_destination = input("Enter your favourite holiday destination: ")

# %% [markdown]
# ### Photo destination<a id="heading-title4"></a>

# %% [markdown]
# ![pacific-coast-highway-header.jpeg](attachment:pacific-coast-highway-header.jpeg)

# %% [markdown]
# ### Things to do<a id="heading-title5"></a>

# %% [markdown]
#  - <font color=blue>Eating</font>
#  - <font color=red>Hiking</font>
#  - **Exploring**

# %% [markdown]
# ### Video<a id="heading-title6"></a>

# %% [markdown]
# [Pacific Coast Highway 1](https://youtu.be/-nmO_rRl8ss)
