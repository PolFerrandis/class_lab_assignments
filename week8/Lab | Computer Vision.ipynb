# %% [markdown]
# ## In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue.

# %% [markdown]
# https://innodata.com/ethical-issues-in-computer-vision-and-strategies-for-success/

# %% [markdown]
# Something that opens a full new world of opportunities always entail some risks if misused or not regulated.
# My opinion is that as these CV tools are already part of our lives, therefore the necessary measures must be taken from companies who develop these technologies but also for governments to find the best fit for our society.

# %% [markdown]
# ## use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done

# %%
# %matplotlib inline
from IPython.display import Image
Image('giraffebycar.png')

# %% [markdown]
# https://vision-explorer.allenai.org/text_to_image_generation
#
# The machine has managed to bring the right elements, car, giraff and background.
#
# However it hasn't done a very good job at orgizing the parts of the elements.

# %% [markdown]
# ## read this blog article. Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.

# %% [markdown]
# ### Specifically, what did the coder have to do to PROCESS the images in the cat v dogs dataset to enable the image classification method to be accurate

# %% [markdown]
# https://thedatafrog.com/en/articles/dogs-vs-cats/

# %% [markdown]
# In order to improve the accuracy the coder used a technique called Data augmentation. This consists in generating new training examples from the ones we already have, in such a way as to increase artificially the size of the training sample.
# These transformations produce new images that are perfectly acceptable so the coder decided to retrain the network with data augmentation.
# With data augmentation, the training took longer, but overfitting was much reduced, and the coder could reach a classification accuracy of 92%.
